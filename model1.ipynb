# %% [markdown]
# import important libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("areaprice071.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# split data into independent and dependent variable

# %%
x=df[["area"]]
y=df.price

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [markdown]
# Data visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Area Price Modeling")
plt.xlabel("Value of Area")
plt.ylabel("Value of price")
plt.scatter(x,y,color="red")

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\abhishek\appdata\local\programs\python\python313\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\abhishek\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\abhishek\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abhishek\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abhishek\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
i= int(input("Enter the area:"))
    
c= model.predict([[i]])
print("price is:",c[0])
# Out:
# Enter the area: 5000
# price is: 859554.7945205481
# C:\Users\ABHISHEK\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
m=model.coef_

# %%
c=model.intercept_

# %%
m*5000+c
# Out:
# array([859554.79452055])

# %%
model.predict(x)
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])
