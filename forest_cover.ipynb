# %%
  import pandas as pd

# %%
import numpy as np

# %%
df = ("abhishek)
# Out:
#   Cell In[13], line 1
#     df = ("abhishek)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)
